# %%
import numpy as np
import matplotlib.pyplot as plt

# Sample data
house_sizes = np.array([1500, 1700, 2000, 2100, 2300])  # Example feature: house sizes
house_prices = np.array([300000, 350000, 400000, 410000, 450000])  # Example target: house prices

# %%
# Parameters
learning_rate = 0.00000001
num_iterations = 1000

# Initialize weights and bias
weight = 0.0
bias = 0.0

# Number of training examples
m = len(house_sizes)

# Gradient Descent
for i in range(num_iterations):
    # Predictions
    predictions = weight * house_sizes + bias
    
    # Calculate the error
    error = predictions - house_prices
    
    # Compute gradients
    weight_gradient = (2/m) * np.dot(house_sizes, error)
    bias_gradient = (2/m) * np.sum(error)
    
    # Update weights and bias
    weight -= learning_rate * weight_gradient
    bias -= learning_rate * bias_gradient
    
    # Print progress every 100 iterations
    if i % 100 == 0:
        cost = (1/m) * np.sum(error ** 2)
        print(f"Iteration {i}: Cost {cost}, Weight {weight}, Bias {bias}")

# Final parameters
print(f"Final Weight: {weight}, Final Bias: {bias}")

# Plotting
plt.figure(figsize=(10, 6))

# Scatter plot of the data
plt.scatter(house_sizes, house_prices, color='blue', label='Data Points')

# Line of regression
regression_line = weight * house_sizes + bias
plt.plot(house_sizes, regression_line, color='red', label='Regression Line')

# Labels and title
plt.xlabel('House Size (sq ft)')
plt.ylabel('House Price ($)')
plt.title('House Prices vs. Size with Regression Line')
plt.legend()

# Show plot
plt.show()
# Out:
# Iteration 0: Cost 148620000000.0, Weight 14.964, Bias 0.00764
# Iteration 100: Cost 52284244.02590251, Weight 198.49419171558182, Bias 0.10266174986268779
# Iteration 200: Cost 52260989.88851994, Weight 198.5667972508844, Bias 0.10420192654705919
# Iteration 300: Cost 52260987.62533089, Weight 198.56682520868083, Bias 0.10570512096101341
# Iteration 400: Cost 52260985.36578105, Weight 198.56682445409274, Bias 0.10720830067934746
# Iteration 500: Cost 52260983.10623144, Weight 198.56682368814592, Bias 0.10871148032678755
# Iteration 600: Cost 52260980.846682034, Weight 198.56682292219455, Bias 0.11021465990911912
# Iteration 700: Cost 52260978.58713254, Weight 198.56682215624318, Bias 0.11171783942634476
# Iteration 800: Cost 52260976.32758359, Weight 198.5668213902919, Bias 0.11322101887846461
# Iteration 900: Cost 52260974.06803495, Weight 198.5668206243406, Bias 0.11472419826547862
# Final Weight: 198.56681986604886, Final Bias: 0.11621234579448998
